# %%
import pandas as pd
import io
import ftplib
import requests
import requests_html
import yahoo_fin
from yahoo_fin.stock_info import *
import ssl
ssl._create_default_https_context= ssl._create_unverified_context

# %%
a = get_stats('AMAZ')
a
# Out:
#                            Attribute         Value
# 0                  Beta (5Y Monthly)          2.46
# 1                   52-Week Change 3       -95.83%
# 2            S&P500 52-Week Change 3         5.66%
# 3                     52 Week High 3        0.2000
# 4                      52 Week Low 3        0.0014
# 5            50-Day Moving Average 3        0.0076
# 6           200-Day Moving Average 3        0.0539
# 7                Avg Vol (3 month) 3        32.24M
# 8                 Avg Vol (10 day) 3         2.94M
# 9               Shares Outstanding 5         98.1M
# 10                             Float           66M
# 11              % Held by Insiders 1        47.48%
# 12          % Held by Institutions 1         0.00%
# 13                    Shares Short 4           NaN
# 14                     Short Ratio 4           NaN
# 15                Short % of Float 4           NaN
# 16   Short % of Shares Outstanding 4           NaN
# 17     Shares Short (prior month ) 4           NaN
# 18    Forward Annual Dividend Rate 4           NaN
# 19   Forward Annual Dividend Yield 4           NaN
# 20   Trailing Annual Dividend Rate 3           NaN
# 21  Trailing Annual Dividend Yield 3           NaN
# 22   5 Year Average Dividend Yield 4           NaN
# 23                    Payout Ratio 4         0.00%
# 24                   Dividend Date 3           NaN
# 25                Ex-Dividend Date 4           NaN
# 26               Last Split Factor 2          1:40
# 27                 Last Split Date 3  Apr 09, 2015
# 28                  Fiscal Year Ends  Jul 30, 2019
# 29         Most Recent Quarter (mrq)  Jan 30, 2020
# 30                     Profit Margin         0.00%
# 31            Operating Margin (ttm)      -821.37%
# 32            Return on Assets (ttm)       -32.97%
# 33            Return on Equity (ttm)      -561.02%
# 34                     Revenue (ttm)       848.33k
# 35           Revenue Per Share (ttm)          0.01
# 36    Quarterly Revenue Growth (yoy)       159.90%
# 37                Gross Profit (ttm)       -23.26k
# 38                            EBITDA        -4.31M
# 39    Net Income Avi to Common (ttm)        -9.62M
# 40                 Diluted EPS (ttm)       -0.1040
# 41   Quarterly Earnings Growth (yoy)           NaN
# 42                  Total Cash (mrq)         78.6k
# 43        Total Cash Per Share (mrq)             0
# 44                  Total Debt (mrq)          7.2M
# 45           Total Debt/Equity (mrq)           NaN
# 46               Current Ratio (mrq)          0.05
# 47        Book Value Per Share (mrq)         -0.01
# 48         Operating Cash Flow (ttm)         1.84M
# 49      Levered Free Cash Flow (ttm)        -3.59M
